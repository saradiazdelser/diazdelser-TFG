# %%
from tqdm.notebook import tqdm
import visualize as vis
import utils as ut
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## TSNE Dimensional Reduction of Documents

# %% [markdown]
# ### Patents

# %%
# Select model
n_topics = 20
docs =f'results/patents/lda_mallet_model_{n_topics}/mallet_output/doc-topics.txt'
tsne_input = ut.read_doc_topics(docs)
tsne = ut.tsne_model(tsne_input)

# Open dataframe
patents = ut.unpickler('app_data/data/patents_dataframe.pkl')

# Join both dataframes
patents.drop_duplicates('Patent ID', inplace=True)
patents = patents.set_index('Patent ID',  drop=False)
joined_df = tsne.join(patents)
ut.pickler('app_data/data/patents_tsne.pkl', joined_df)

# Create hover text
HOVER_TEXT = vis.create_hovertexts(joined_df, 'patents')

# Visualize
fig1 = vis.display_documents_tsme(joined_df,n_topics,HOVER_TEXT)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1961 samples in 0.000s...
# [t-SNE] Computed neighbors for 1961 samples in 0.151s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1961
# [t-SNE] Computed conditional probabilities for sample 1961 / 1961
# [t-SNE] Mean sigma: 0.099918
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.508530
# [t-SNE] KL divergence after 1000 iterations: 0.689350

# %%
fig1.write_image('img/tsne_patents.png', format='png',engine='kaleido')

# %% [markdown]
# ### Cordis

# %%
# Select model
n_topics = 15
docs =f'results/cordis/lda_mallet_model_{n_topics}/mallet_output/doc-topics.txt'
tsne_input = ut.read_doc_topics(docs)
tsne = ut.tsne_model(tsne_input)

# Open dataframe
cordis = ut.unpickler('app_data/data/cordis_dataframe.pkl')

# Join both dataframes
cordis.drop_duplicates('Project ID', inplace=True)
cordis = cordis.set_index('Project ID',  drop=False)
cordis['Year'] = cordis.apply(lambda row: str(row['Start Year']).split('-')[0], axis=1)

joined_df = tsne.join(cordis)
ut.pickler('app_data/data/cordis_tsne.pkl', joined_df)

# Create hover text
HOVER_TEXT = vis.create_hovertexts(joined_df, 'cordis')

# Visualize
fig2 = vis.display_documents_tsme(joined_df,n_topics,HOVER_TEXT)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 19838 samples in 0.021s...
# [t-SNE] Computed neighbors for 19838 samples in 8.143s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19838
# [t-SNE] Computed conditional probabilities for sample 2000 / 19838
# [t-SNE] Computed conditional probabilities for sample 3000 / 19838
# [t-SNE] Computed conditional probabilities for sample 4000 / 19838
# [t-SNE] Computed conditional probabilities for sample 5000 / 19838
# [t-SNE] Computed conditional probabilities for sample 6000 / 19838
# [t-SNE] Computed conditional probabilities for sample 7000 / 19838
# [t-SNE] Computed conditional probabilities for sample 8000 / 19838
# [t-SNE] Computed conditional probabilities for sample 9000 / 19838
# [t-SNE] Computed conditional probabilities for sample 10000 / 19838
# [t-SNE] Computed conditional probabilities for sample 11000 / 19838
# [t-SNE] Computed conditional probabilities for sample 12000 / 19838
# [t-SNE] Computed conditional probabilities for sample 13000 / 19838
# [t-SNE] Computed conditional probabilities for sample 14000 / 19838
# [t-SNE] Computed conditional probabilities for sample 15000 / 19838
# [t-SNE] Computed conditional probabilities for sample 16000 / 19838
# [t-SNE] Computed conditional probabilities for sample 17000 / 19838
# [t-SNE] Computed conditional probabilities for sample 18000 / 19838
# [t-SNE] Computed conditional probabilities for sample 19000 / 19838
# [t-SNE] Computed conditional probabilities for sample 19838 / 19838
# [t-SNE] Mean sigma: 0.053268
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 87.508377
# [t-SNE] KL divergence after 1000 iterations: 1.625049

# %%
fig2.write_image('img/tsne_cordis.png', format='png',engine='kaleido')

# %% [markdown]
# ### Semantic Scholar

# %%
# Select model
n_topics = 20
'doc-topics.txt'
docs =f'results/semantic_scholar/lda_mallet_model_{n_topics}/mallet_output/doc-topics.txt'
tsne_input = ut.read_doc_topics(docs)
tsne = ut.tsne_model(tsne_input)

# Open dataframe
semantic_scholar = ut.unpickler('app_data/data/semantic_scholar_dataframe.pkl')

# Join both dataframes
semantic_scholar.drop_duplicates('Publication ID', inplace=True)
semantic_scholar = semantic_scholar.set_index('Publication ID',  drop=False)
joined_df = tsne.join(semantic_scholar)
ut.pickler('app_data/data/semantic_scholar_tsne.pkl', joined_df)

# Create hover text
HOVER_TEXT = vis.create_hovertexts(joined_df, 'semantic_scholar')

# Visualize
fig3 = vis.display_documents_tsme(joined_df,n_topics,HOVER_TEXT)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 306844 samples in 0.019s...
# [t-SNE] Computed neighbors for 306844 samples in 226.706s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 306844
# [t-SNE] Computed conditional probabilities for sample 2000 / 306844
# [t-SNE] Computed conditional probabilities for sample 3000 / 306844
# [t-SNE] Computed conditional probabilities for sample 4000 / 306844
# [t-SNE] Computed conditional probabilities for sample 5000 / 306844
# [t-SNE] Computed conditional probabilities for sample 6000 / 306844
# [t-SNE] Computed conditional probabilities for sample 7000 / 306844
# [t-SNE] Computed conditional probabilities for sample 8000 / 306844
# [t-SNE] Computed conditional probabilities for sample 9000 / 306844
# [t-SNE] Computed conditional probabilities for sample 10000 / 306844
# [t-SNE] Computed conditional probabilities for sample 11000 / 306844
# [t-SNE] Computed conditional probabilities for sample 12000 / 306844
# [t-SNE] Computed conditional probabilities for sample 13000 / 306844
# [t-SNE] Computed conditional probabilities for sample 14000 / 306844
# [t-SNE] Computed conditional probabilities for sample 15000 / 306844
# [t-SNE] Computed conditional probabilities for sample 16000 / 306844
# [t-SNE] Computed conditional probabilities for sample 17000 / 306844
# [t-SNE] Computed conditional probabilities for sample 18000 / 306844
# [t-SNE] Computed conditional probabilities for sample 19000 / 306844
# [t-SNE] Computed conditional probabilities for sample 20000 / 306844
# [t-SNE] Computed conditional probabilities for sample 21000 / 306844
# [t-SNE] Computed conditional probabilities for sample 22000 / 306844
# [t-SNE] Computed conditional probabilities for sample 23000 / 306844
# [t-SNE] Computed conditional probabilities for sample 24000 / 306844
# [t-SNE] Computed conditional probabilities for sample 25000 / 306844
# [t-SNE] Computed conditional probabilities for sample 26000 / 306844
# [t-SNE] Computed conditional probabilities for sample 27000 / 306844
# [t-SNE] Computed conditional probabilities for sample 28000 / 306844
# [t-SNE] Computed conditional probabilities for sample 29000 / 306844
# [t-SNE] Computed conditional probabilities for sample 30000 / 306844
# [t-SNE] Computed conditional probabilities for sample 31000 / 306844
# [t-SNE] Computed conditional probabilities for sample 32000 / 306844
# [t-SNE] Computed conditional probabilities for sample 33000 / 306844
# [t-SNE] Computed conditional probabilities for sample 34000 / 306844
# [t-SNE] Computed conditional probabilities for sample 35000 / 306844
# [t-SNE] Computed conditional probabilities for sample 36000 / 306844
# [t-SNE] Computed conditional probabilities for sample 37000 / 306844
# [t-SNE] Computed conditional probabilities for sample 38000 / 306844
# [t-SNE] Computed conditional probabilities for sample 39000 / 306844
# [t-SNE] Computed conditional probabilities for sample 40000 / 306844
# [t-SNE] Computed conditional probabilities for sample 41000 / 306844
# [t-SNE] Computed conditional probabilities for sample 42000 / 306844
# [t-SNE] Computed conditional probabilities for sample 43000 / 306844
# [t-SNE] Computed conditional probabilities for sample 44000 / 306844
# [t-SNE] Computed conditional probabilities for sample 45000 / 306844
# [t-SNE] Computed conditional probabilities for sample 46000 / 306844
# [t-SNE] Computed conditional probabilities for sample 47000 / 306844
# [t-SNE] Computed conditional probabilities for sample 48000 / 306844
# [t-SNE] Computed conditional probabilities for sample 49000 / 306844
# [t-SNE] Computed conditional probabilities for sample 50000 / 306844
# [t-SNE] Computed conditional probabilities for sample 51000 / 306844
# [t-SNE] Computed conditional probabilities for sample 52000 / 306844
# [t-SNE] Computed conditional probabilities for sample 53000 / 306844
# [t-SNE] Computed conditional probabilities for sample 54000 / 306844
# [t-SNE] Computed conditional probabilities for sample 55000 / 306844
# [t-SNE] Computed conditional probabilities for sample 56000 / 306844
# [t-SNE] Computed conditional probabilities for sample 57000 / 306844
# [t-SNE] Computed conditional probabilities for sample 58000 / 306844
# [t-SNE] Computed conditional probabilities for sample 59000 / 306844
# [t-SNE] Computed conditional probabilities for sample 60000 / 306844
# [t-SNE] Computed conditional probabilities for sample 61000 / 306844
# [t-SNE] Computed conditional probabilities for sample 62000 / 306844
# [t-SNE] Computed conditional probabilities for sample 63000 / 306844
# [t-SNE] Computed conditional probabilities for sample 64000 / 306844
# [t-SNE] Computed conditional probabilities for sample 65000 / 306844
# [t-SNE] Computed conditional probabilities for sample 66000 / 306844
# [t-SNE] Computed conditional probabilities for sample 67000 / 306844
# [t-SNE] Computed conditional probabilities for sample 68000 / 306844
# [t-SNE] Computed conditional probabilities for sample 69000 / 306844
# [t-SNE] Computed conditional probabilities for sample 70000 / 306844
# [t-SNE] Computed conditional probabilities for sample 71000 / 306844
# [t-SNE] Computed conditional probabilities for sample 72000 / 306844
# [t-SNE] Computed conditional probabilities for sample 73000 / 306844
# [t-SNE] Computed conditional probabilities for sample 74000 / 306844
# [t-SNE] Computed conditional probabilities for sample 75000 / 306844
# [t-SNE] Computed conditional probabilities for sample 76000 / 306844
# [t-SNE] Computed conditional probabilities for sample 77000 / 306844
# [t-SNE] Computed conditional probabilities for sample 78000 / 306844
# [t-SNE] Computed conditional probabilities for sample 79000 / 306844
# [t-SNE] Computed conditional probabilities for sample 80000 / 306844
# [t-SNE] Computed conditional probabilities for sample 81000 / 306844
# [t-SNE] Computed conditional probabilities for sample 82000 / 306844
# [t-SNE] Computed conditional probabilities for sample 83000 / 306844
# [t-SNE] Computed conditional probabilities for sample 84000 / 306844
# [t-SNE] Computed conditional probabilities for sample 85000 / 306844
# [t-SNE] Computed conditional probabilities for sample 86000 / 306844
# [t-SNE] Computed conditional probabilities for sample 87000 / 306844
# [t-SNE] Computed conditional probabilities for sample 88000 / 306844
# [t-SNE] Computed conditional probabilities for sample 89000 / 306844
# [t-SNE] Computed conditional probabilities for sample 90000 / 306844
# [t-SNE] Computed conditional probabilities for sample 91000 / 306844
# [t-SNE] Computed conditional probabilities for sample 92000 / 306844
# [t-SNE] Computed conditional probabilities for sample 93000 / 306844
# [t-SNE] Computed conditional probabilities for sample 94000 / 306844
# [t-SNE] Computed conditional probabilities for sample 95000 / 306844
# [t-SNE] Computed conditional probabilities for sample 96000 / 306844
# [t-SNE] Computed conditional probabilities for sample 97000 / 306844
# [t-SNE] Computed conditional probabilities for sample 98000 / 306844
# [t-SNE] Computed conditional probabilities for sample 99000 / 306844
# [t-SNE] Computed conditional probabilities for sample 100000 / 306844
# [t-SNE] Computed conditional probabilities for sample 101000 / 306844
# [t-SNE] Computed conditional probabilities for sample 102000 / 306844
# [t-SNE] Computed conditional probabilities for sample 103000 / 306844
# [t-SNE] Computed conditional probabilities for sample 104000 / 306844
# [t-SNE] Computed conditional probabilities for sample 105000 / 306844
# [t-SNE] Computed conditional probabilities for sample 106000 / 306844
# [t-SNE] Computed conditional probabilities for sample 107000 / 306844
# [t-SNE] Computed conditional probabilities for sample 108000 / 306844
# [t-SNE] Computed conditional probabilities for sample 109000 / 306844
# [t-SNE] Computed conditional probabilities for sample 110000 / 306844
# [t-SNE] Computed conditional probabilities for sample 111000 / 306844
# [t-SNE] Computed conditional probabilities for sample 112000 / 306844
# [t-SNE] Computed conditional probabilities for sample 113000 / 306844
# [t-SNE] Computed conditional probabilities for sample 114000 / 306844
# [t-SNE] Computed conditional probabilities for sample 115000 / 306844
# [t-SNE] Computed conditional probabilities for sample 116000 / 306844
# [t-SNE] Computed conditional probabilities for sample 117000 / 306844
# [t-SNE] Computed conditional probabilities for sample 118000 / 306844
# [t-SNE] Computed conditional probabilities for sample 119000 / 306844
# [t-SNE] Computed conditional probabilities for sample 120000 / 306844
# [t-SNE] Computed conditional probabilities for sample 121000 / 306844
# [t-SNE] Computed conditional probabilities for sample 122000 / 306844
# [t-SNE] Computed conditional probabilities for sample 123000 / 306844
# [t-SNE] Computed conditional probabilities for sample 124000 / 306844
# [t-SNE] Computed conditional probabilities for sample 125000 / 306844
# [t-SNE] Computed conditional probabilities for sample 126000 / 306844
# [t-SNE] Computed conditional probabilities for sample 127000 / 306844
# [t-SNE] Computed conditional probabilities for sample 128000 / 306844
# [t-SNE] Computed conditional probabilities for sample 129000 / 306844
# [t-SNE] Computed conditional probabilities for sample 130000 / 306844
# [t-SNE] Computed conditional probabilities for sample 131000 / 306844
# [t-SNE] Computed conditional probabilities for sample 132000 / 306844
# [t-SNE] Computed conditional probabilities for sample 133000 / 306844
# [t-SNE] Computed conditional probabilities for sample 134000 / 306844
# [t-SNE] Computed conditional probabilities for sample 135000 / 306844
# [t-SNE] Computed conditional probabilities for sample 136000 / 306844
# [t-SNE] Computed conditional probabilities for sample 137000 / 306844
# [t-SNE] Computed conditional probabilities for sample 138000 / 306844
# [t-SNE] Computed conditional probabilities for sample 139000 / 306844
# [t-SNE] Computed conditional probabilities for sample 140000 / 306844
# [t-SNE] Computed conditional probabilities for sample 141000 / 306844
# [t-SNE] Computed conditional probabilities for sample 142000 / 306844
# [t-SNE] Computed conditional probabilities for sample 143000 / 306844
# [t-SNE] Computed conditional probabilities for sample 144000 / 306844
# [t-SNE] Computed conditional probabilities for sample 145000 / 306844
# [t-SNE] Computed conditional probabilities for sample 146000 / 306844
# [t-SNE] Computed conditional probabilities for sample 147000 / 306844
# [t-SNE] Computed conditional probabilities for sample 148000 / 306844
# [t-SNE] Computed conditional probabilities for sample 149000 / 306844
# [t-SNE] Computed conditional probabilities for sample 150000 / 306844
# [t-SNE] Computed conditional probabilities for sample 151000 / 306844
# [t-SNE] Computed conditional probabilities for sample 152000 / 306844
# [t-SNE] Computed conditional probabilities for sample 153000 / 306844
# [t-SNE] Computed conditional probabilities for sample 154000 / 306844
# [t-SNE] Computed conditional probabilities for sample 155000 / 306844
# [t-SNE] Computed conditional probabilities for sample 156000 / 306844
# [t-SNE] Computed conditional probabilities for sample 157000 / 306844
# [t-SNE] Computed conditional probabilities for sample 158000 / 306844
# [t-SNE] Computed conditional probabilities for sample 159000 / 306844
# [t-SNE] Computed conditional probabilities for sample 160000 / 306844
# [t-SNE] Computed conditional probabilities for sample 161000 / 306844
# [t-SNE] Computed conditional probabilities for sample 162000 / 306844
# [t-SNE] Computed conditional probabilities for sample 163000 / 306844
# [t-SNE] Computed conditional probabilities for sample 164000 / 306844
# [t-SNE] Computed conditional probabilities for sample 165000 / 306844
# [t-SNE] Computed conditional probabilities for sample 166000 / 306844
# [t-SNE] Computed conditional probabilities for sample 167000 / 306844
# [t-SNE] Computed conditional probabilities for sample 168000 / 306844
# [t-SNE] Computed conditional probabilities for sample 169000 / 306844
# [t-SNE] Computed conditional probabilities for sample 170000 / 306844
# [t-SNE] Computed conditional probabilities for sample 171000 / 306844
# [t-SNE] Computed conditional probabilities for sample 172000 / 306844
# [t-SNE] Computed conditional probabilities for sample 173000 / 306844
# [t-SNE] Computed conditional probabilities for sample 174000 / 306844
# [t-SNE] Computed conditional probabilities for sample 175000 / 306844
# [t-SNE] Computed conditional probabilities for sample 176000 / 306844
# [t-SNE] Computed conditional probabilities for sample 177000 / 306844
# [t-SNE] Computed conditional probabilities for sample 178000 / 306844
# [t-SNE] Computed conditional probabilities for sample 179000 / 306844
# [t-SNE] Computed conditional probabilities for sample 180000 / 306844
# [t-SNE] Computed conditional probabilities for sample 181000 / 306844
# [t-SNE] Computed conditional probabilities for sample 182000 / 306844
# [t-SNE] Computed conditional probabilities for sample 183000 / 306844
# [t-SNE] Computed conditional probabilities for sample 184000 / 306844
# [t-SNE] Computed conditional probabilities for sample 185000 / 306844
# [t-SNE] Computed conditional probabilities for sample 186000 / 306844
# [t-SNE] Computed conditional probabilities for sample 187000 / 306844
# [t-SNE] Computed conditional probabilities for sample 188000 / 306844
# [t-SNE] Computed conditional probabilities for sample 189000 / 306844
# [t-SNE] Computed conditional probabilities for sample 190000 / 306844
# [t-SNE] Computed conditional probabilities for sample 191000 / 306844
# [t-SNE] Computed conditional probabilities for sample 192000 / 306844
# [t-SNE] Computed conditional probabilities for sample 193000 / 306844
# [t-SNE] Computed conditional probabilities for sample 194000 / 306844
# [t-SNE] Computed conditional probabilities for sample 195000 / 306844
# [t-SNE] Computed conditional probabilities for sample 196000 / 306844
# [t-SNE] Computed conditional probabilities for sample 197000 / 306844
# [t-SNE] Computed conditional probabilities for sample 198000 / 306844
# [t-SNE] Computed conditional probabilities for sample 199000 / 306844
# [t-SNE] Computed conditional probabilities for sample 200000 / 306844
# [t-SNE] Computed conditional probabilities for sample 201000 / 306844
# [t-SNE] Computed conditional probabilities for sample 202000 / 306844
# [t-SNE] Computed conditional probabilities for sample 203000 / 306844
# [t-SNE] Computed conditional probabilities for sample 204000 / 306844
# [t-SNE] Computed conditional probabilities for sample 205000 / 306844
# [t-SNE] Computed conditional probabilities for sample 206000 / 306844
# [t-SNE] Computed conditional probabilities for sample 207000 / 306844
# [t-SNE] Computed conditional probabilities for sample 208000 / 306844
# [t-SNE] Computed conditional probabilities for sample 209000 / 306844
# [t-SNE] Computed conditional probabilities for sample 210000 / 306844
# [t-SNE] Computed conditional probabilities for sample 211000 / 306844
# [t-SNE] Computed conditional probabilities for sample 212000 / 306844
# [t-SNE] Computed conditional probabilities for sample 213000 / 306844
# [t-SNE] Computed conditional probabilities for sample 214000 / 306844
# [t-SNE] Computed conditional probabilities for sample 215000 / 306844
# [t-SNE] Computed conditional probabilities for sample 216000 / 306844
# [t-SNE] Computed conditional probabilities for sample 217000 / 306844
# [t-SNE] Computed conditional probabilities for sample 218000 / 306844
# [t-SNE] Computed conditional probabilities for sample 219000 / 306844
# [t-SNE] Computed conditional probabilities for sample 220000 / 306844
# [t-SNE] Computed conditional probabilities for sample 221000 / 306844
# [t-SNE] Computed conditional probabilities for sample 222000 / 306844
# [t-SNE] Computed conditional probabilities for sample 223000 / 306844
# [t-SNE] Computed conditional probabilities for sample 224000 / 306844
# [t-SNE] Computed conditional probabilities for sample 225000 / 306844
# [t-SNE] Computed conditional probabilities for sample 226000 / 306844
# [t-SNE] Computed conditional probabilities for sample 227000 / 306844
# [t-SNE] Computed conditional probabilities for sample 228000 / 306844
# [t-SNE] Computed conditional probabilities for sample 229000 / 306844
# [t-SNE] Computed conditional probabilities for sample 230000 / 306844
# [t-SNE] Computed conditional probabilities for sample 231000 / 306844
# [t-SNE] Computed conditional probabilities for sample 232000 / 306844
# [t-SNE] Computed conditional probabilities for sample 233000 / 306844
# [t-SNE] Computed conditional probabilities for sample 234000 / 306844
# [t-SNE] Computed conditional probabilities for sample 235000 / 306844
# [t-SNE] Computed conditional probabilities for sample 236000 / 306844
# [t-SNE] Computed conditional probabilities for sample 237000 / 306844
# [t-SNE] Computed conditional probabilities for sample 238000 / 306844
# [t-SNE] Computed conditional probabilities for sample 239000 / 306844
# [t-SNE] Computed conditional probabilities for sample 240000 / 306844
# [t-SNE] Computed conditional probabilities for sample 241000 / 306844
# [t-SNE] Computed conditional probabilities for sample 242000 / 306844
# [t-SNE] Computed conditional probabilities for sample 243000 / 306844
# [t-SNE] Computed conditional probabilities for sample 244000 / 306844
# [t-SNE] Computed conditional probabilities for sample 245000 / 306844
# [t-SNE] Computed conditional probabilities for sample 246000 / 306844
# [t-SNE] Computed conditional probabilities for sample 247000 / 306844
# [t-SNE] Computed conditional probabilities for sample 248000 / 306844
# [t-SNE] Computed conditional probabilities for sample 249000 / 306844
# [t-SNE] Computed conditional probabilities for sample 250000 / 306844
# [t-SNE] Computed conditional probabilities for sample 251000 / 306844
# [t-SNE] Computed conditional probabilities for sample 252000 / 306844
# [t-SNE] Computed conditional probabilities for sample 253000 / 306844
# [t-SNE] Computed conditional probabilities for sample 254000 / 306844
# [t-SNE] Computed conditional probabilities for sample 255000 / 306844
# [t-SNE] Computed conditional probabilities for sample 256000 / 306844
# [t-SNE] Computed conditional probabilities for sample 257000 / 306844
# [t-SNE] Computed conditional probabilities for sample 258000 / 306844
# [t-SNE] Computed conditional probabilities for sample 259000 / 306844
# [t-SNE] Computed conditional probabilities for sample 260000 / 306844
# [t-SNE] Computed conditional probabilities for sample 261000 / 306844
# [t-SNE] Computed conditional probabilities for sample 262000 / 306844
# [t-SNE] Computed conditional probabilities for sample 263000 / 306844
# [t-SNE] Computed conditional probabilities for sample 264000 / 306844
# [t-SNE] Computed conditional probabilities for sample 265000 / 306844
# [t-SNE] Computed conditional probabilities for sample 266000 / 306844
# [t-SNE] Computed conditional probabilities for sample 267000 / 306844
# [t-SNE] Computed conditional probabilities for sample 268000 / 306844
# [t-SNE] Computed conditional probabilities for sample 269000 / 306844
# [t-SNE] Computed conditional probabilities for sample 270000 / 306844
# [t-SNE] Computed conditional probabilities for sample 271000 / 306844
# [t-SNE] Computed conditional probabilities for sample 272000 / 306844
# [t-SNE] Computed conditional probabilities for sample 273000 / 306844
# [t-SNE] Computed conditional probabilities for sample 274000 / 306844
# [t-SNE] Computed conditional probabilities for sample 275000 / 306844
# [t-SNE] Computed conditional probabilities for sample 276000 / 306844
# [t-SNE] Computed conditional probabilities for sample 277000 / 306844
# [t-SNE] Computed conditional probabilities for sample 278000 / 306844
# [t-SNE] Computed conditional probabilities for sample 279000 / 306844
# [t-SNE] Computed conditional probabilities for sample 280000 / 306844
# [t-SNE] Computed conditional probabilities for sample 281000 / 306844
# [t-SNE] Computed conditional probabilities for sample 282000 / 306844
# [t-SNE] Computed conditional probabilities for sample 283000 / 306844
# [t-SNE] Computed conditional probabilities for sample 284000 / 306844
# [t-SNE] Computed conditional probabilities for sample 285000 / 306844
# [t-SNE] Computed conditional probabilities for sample 286000 / 306844
# [t-SNE] Computed conditional probabilities for sample 287000 / 306844
# [t-SNE] Computed conditional probabilities for sample 288000 / 306844
# [t-SNE] Computed conditional probabilities for sample 289000 / 306844
# [t-SNE] Computed conditional probabilities for sample 290000 / 306844
# [t-SNE] Computed conditional probabilities for sample 291000 / 306844
# [t-SNE] Computed conditional probabilities for sample 292000 / 306844
# [t-SNE] Computed conditional probabilities for sample 293000 / 306844
# [t-SNE] Computed conditional probabilities for sample 294000 / 306844
# [t-SNE] Computed conditional probabilities for sample 295000 / 306844
# [t-SNE] Computed conditional probabilities for sample 296000 / 306844
# [t-SNE] Computed conditional probabilities for sample 297000 / 306844
# [t-SNE] Computed conditional probabilities for sample 298000 / 306844
# [t-SNE] Computed conditional probabilities for sample 299000 / 306844
# [t-SNE] Computed conditional probabilities for sample 300000 / 306844
# [t-SNE] Computed conditional probabilities for sample 301000 / 306844
# [t-SNE] Computed conditional probabilities for sample 302000 / 306844
# [t-SNE] Computed conditional probabilities for sample 303000 / 306844
# [t-SNE] Computed conditional probabilities for sample 304000 / 306844
# [t-SNE] Computed conditional probabilities for sample 305000 / 306844
# [t-SNE] Computed conditional probabilities for sample 306000 / 306844
# [t-SNE] Computed conditional probabilities for sample 306844 / 306844
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 112.497612
# [t-SNE] KL divergence after 1000 iterations: 4.354349

# %%
fig3.write_image('img/tsne_semantic_scholar.png', format='png',engine='kaleido')
